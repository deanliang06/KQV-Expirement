# %% [markdown]
# # KQV-Expirement Colab Entrypoint
#
# This notebook is the fastest way to boot the repo in Google Colab.
#
# Use a GPU runtime: `Runtime -> Change runtime type -> T4 GPU`.

# %%
from pathlib import Path

REPO_URL = "https://github.com/deanliang06/KQV-Expirement"
REPO_DIR = Path("/content/KQV-Expirement")

if not REPO_DIR.exists():
    if not REPO_URL:
        raise ValueError("Set REPO_URL to your GitHub clone URL before running this cell.")
    # !git clone {REPO_URL} {REPO_DIR}

# %cd {REPO_DIR}
print(f"Working from: {REPO_DIR}")

# %%
# %pip install -q -r requirements.txt

# %%
import torch
print("CUDA available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))

# %% [markdown]
# ## Quick Smoke Test
#
# Run the lightest experiment first so you can verify the environment before trying the U-Net runs.

# %%
# !python -m svd_baseline_experiment.load --rank 128

# %% [markdown]
# ## Optional Runs
#
# Uncomment one of these when you want a heavier run.

# %%
# !python -m compare_q_experiments
# !python -m unet_embedding_bottleneck.load
# !python -m unet_embedding_bottleneck.eval
# !python -m unet_original.load
# !python -m unet_original.eval
